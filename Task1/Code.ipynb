# %% [markdown]
# # Data Science Intern @Lets Grow More
# # September

# %% [markdown]
# # Developer :Abhinav Pratap Singh

# %% [markdown]
# # Task 1  :Iris Flower Classification ML Level

# %% [markdown]
# # Importing the packages and libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pingouin as pg

# %% [markdown]
# # Loading the dataset

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# ...

# %%
df.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 69    70            5.6           2.5            3.9           1.1
# 143  144            6.8           3.2            5.9           2.3
# 142  143            5.8           2.7            5.1           1.9
# 74    75            6.4           2.9            4.3           1.3
# 6      7            4.6           3.4            1.4           0.3
#
#              Species
# 69   Iris-versicolor
# 143   Iris-virginica
# 142   Iris-virginica
# 74   Iris-versicolor
# 6        Iris-setosa
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 69    70            5.6           2.5            3.9           1.1
# 143  144            6.8           3.2            5.9           2.3
# 142  143            5.8           2.7            5.1           1.9
# 74    75            6.4           2.9            4.3           1.3
# 6      7            4.6           3.4            1.4           0.3
#
#              Species
# ...

# %%
df.shape
# Out:
# (150, 6)
# (150, 6)

# %%
df = df.drop(columns = ['Id'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# ...

# %%
df.isnull()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            False         False          False         False    False
# 1            False         False          False         False    False
# 2            False         False          False         False    False
# 3            False         False          False         False    False
# 4            False         False          False         False    False
# ..             ...           ...            ...           ...      ...
# 145          False         False          False         False    False
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
#
# [150 rows x 5 columns]
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# ...

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.nunique()
# Out:
# SepalLengthCm    35
# SepalWidthCm     23
# PetalLengthCm    43
# PetalWidthCm     22
# Species           3
# dtype: int64
# SepalLengthCm    35
# SepalWidthCm     23
# PetalLengthCm    43
# PetalWidthCm     22
# Species           3
# dtype: int64

# %% [markdown]
# # Data Visulaisation

# %%
df['SepalLengthCm'].hist()
# Out:
# <AxesSubplot:>
# <AxesSubplot:>

# %%
df['SepalWidthCm'].hist()
# Out:
# <AxesSubplot:>
# <AxesSubplot:>

# %%
def plotting():
    fig,axes=plt.subplots(3,2,figsize=(12,12))
    pg.qqplot(df['SepalLengthCm'],dist='norm',ax=axes[0][0])
    sns.barplot(x=df.Species,y=df['SepalLengthCm'],ax=axes[0][1])
    sns.stripplot(x=df.Species,y=df['SepalLengthCm'],ax=axes[1][0])
    sns.violinplot(y=df['SepalLengthCm'],x=df.Species,hue='Species',data=df,ax=axes[1][1])
    sns.boxplot(y=df['SepalLengthCm'],x=df.Species,hue='Species',data=df,ax=axes[2][0])
    sns.histplot(x=df['SepalLengthCm'],kde=True,bins=10,ax=axes[2][1])
    plt.suptitle('Length of sepal in cm')
    plt.show()

# %%
plotting()

# %%
df['PetalWidthCm'].hist()
# Out:
# <AxesSubplot:>
# <AxesSubplot:>

# %%
def plotting():
    fig,axes=plt.subplots(3,2,figsize=(12,12))
    pg.qqplot(df['SepalWidthCm'],dist='norm',ax=axes[0][0])
    sns.barplot(x=df.Species,y=df['SepalWidthCm'],ax=axes[0][1])
    sns.stripplot(x=df.Species,y=df['SepalWidthCm'],ax=axes[1][0])
    sns.violinplot(y=df['SepalWidthCm'],x=df.Species,hue='Species',data=df,ax=axes[1][1])
    sns.boxplot(y=df['SepalWidthCm'],x=df.Species,hue='Species',data=df,ax=axes[2][0])
    sns.histplot(x=df['SepalWidthCm'],kde=True,bins=10,ax=axes[2][1])
    plt.suptitle('Width of sepal in cm')
    plt.show()

# %%
plotting()

# %%
# scatterplot
colors = ['green', 'yellow', 'blue']
species = ['Iris-virginica','Iris-versicolor','Iris-setosa']
for i in range(3):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['SepalLengthCm'], x['SepalWidthCm'], c = colors[i], label=species[i])
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.legend()

# %%
for i in range(3):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['PetalLengthCm'], x['PetalWidthCm'], c = colors[i], label=species[i])
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.legend()

# %%
plt.figure(figsize = (10, 7))
sns.boxplot(data=df,x='Species',y='SepalLengthCm')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>

# %%
plt.figure(figsize = (10, 7))
sns.boxplot(data=df,x='Species',y='SepalWidthCm')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
plt.figure(figsize = (10, 7))
sns.boxplot(data=df,x='Species',y='PetalLengthCm')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
plt.figure(figsize = (10, 7))
sns.boxplot(data=df,x='Species',y='PetalWidthCm')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %%
plt.plot(df['SepalWidthCm'],'ro')

# %%
plt.plot(df['SepalLengthCm'],'bo')

# %%
plt.plot(df['SepalLengthCm'],'yo')

# %%
sns.pairplot(df, hue="Species")

# %%
plt.subplots(1,1,figsize=(10,8))
df["Species"].value_counts().plot.pie(explode=[0.01,0.01,0.01])
plt.show()

# %%
df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
corr = df.corr()
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corr, annot=True, ax=ax, cmap = 'summer')
# Out:
# <AxesSubplot:>
# <AxesSubplot:>

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Species'] = le.fit_transform(df['Species'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %% [markdown]
# # Splitting the data for training and testing

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns=['Species'])
Y = df['Species']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)

# %% [markdown]
# # Supervised machine learning classification

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# ...

# %%
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  93.33333333333333
# Accuracy:  93.33333333333333

# %% [markdown]
# # KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()
# KNeighborsClassifier()

# %%
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  97.77777777777777
# Accuracy:  97.77777777777777

# %%
# decision tree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()
# DecisionTreeClassifier()

# %%
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  93.33333333333333
# Accuracy:  93.33333333333333

# %%
# removing Id column
new_data = df[["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]]
plt.figure(figsize = (10, 7))
new_data.boxplot()
# Out:
# <AxesSubplot:>
# <AxesSubplot:>
